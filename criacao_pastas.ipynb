# %% [markdown]
# ---Criar pastas automaticamente---

# %%
#importar a biblioteca
import os.path
import os

# %%
meses=['01. Janeiro','02. Fevereiro','03. Março', '04. Abril', '05. Maio', '06. Junho','07. Julho','08. Agosto','09. Setembro','10. Outubro','11. Novembro','12. Dezembro']
gestoras=['BOCAINA','INTER','SANTANDER','SPX','VINCI','WHG','XP']
Sant=['SARE','SADI']
Inter=['LGCP','LUGG','ITIP','ITIT','BIDB']
Xp=['XPIE','XPID']
Bocaina=['BODB']
vinci=['VIUR']
Whg=['WHGR']
spx=['SPXS']
t='G:\\depto\\RENDA\\Natalia_Artilha\\FUNDOS\\'
y='\\RELATÓRIOS\\2023\\'
o='\\'
for x in gestoras:
        if x=='BOCAINA':
            for b in Bocaina:
#G:\depto\RENDA\Formador de Mercado\FUNDOS\SANTANDER\SARE\RELATÓRIOS\2023
                for i in meses:
                    #pasta=os.path.join('G:\\depto\\RENDA\\Natalia_Artilha\\FUNDOS\\', x,'\\',b,'\\RELATÓRIOS\\2023',i)
                    pasta=t+x+o+b+y+i
                    if os.path.isdir(pasta): # vemos de este diretorio ja existe
                        print ('Ja existe uma pasta com esse nome!')
                    else:
                        os.mkdir(pasta) # aqui criamos a pasta caso nao exista
                    print ('Pasta criada com sucesso!')
        if x=='INTER':
            for f in Inter:    
                for i in meses:
                    pasta=t+x+o+f+y+i
                    if os.path.isdir(pasta): # vemos de este diretorio ja existe
                        print ('Ja existe uma pasta com esse nome!')
                    else:
                        os.mkdir(pasta) # aqui criamos a pasta caso nao exista
                    print ('Pasta criada com sucesso!')
        if x=='SANTANDER':
            for s in Sant:    
                for i in meses:
                    pasta=t+x+o+s+y+i
                    if os.path.isdir(pasta): # vemos de este diretorio ja existe
                        print ('Ja existe uma pasta com esse nome!')
                    else:
                        os.mkdir(pasta) # aqui criamos a pasta caso nao exista
                    print ('Pasta criada com sucesso!')
        if x=='XP':
            for v in Xp:    
                for i in meses:
                    pasta=t+x+o+v+y+i
                    if os.path.isdir(pasta): # vemos de este diretorio ja existe
                        print ('Ja existe uma pasta com esse nome!')
                    else:
                        os.mkdir(pasta) # aqui criamos a pasta caso nao exista
                    print ('Pasta criada com sucesso!')
        if x=='VINCI':
            for g in vinci:    
                for i in meses:
                    pasta=t+x+o+g+y+i
                    if os.path.isdir(pasta): # vemos de este diretorio ja existe
                        print ('Ja existe uma pasta com esse nome!')
                    else:
                        os.mkdir(pasta) # aqui criamos a pasta caso nao exista
                    print ('Pasta criada com sucesso!')
        if x=='WHG':
            for w in Whg:    
                for i in meses:
                    pasta=t+x+o+w+y+i
                    if os.path.isdir(pasta): # vemos de este diretorio ja existe
                        print ('Ja existe uma pasta com esse nome!')
                    else:
                        os.mkdir(pasta) # aqui criamos a pasta caso nao exista
                    print ('Pasta criada com sucesso!')
        if x=='SPX':
            for j in spx:    
                for i in meses:
                    pasta=t+x+o+j+y+i
                    if os.path.isdir(pasta): # vemos de este diretorio ja existe
                        print ('Ja existe uma pasta com esse nome!')
                    else:
                        os.mkdir(pasta) # aqui criamos a pasta caso nao exista
                    print ('Pasta criada com sucesso!')
# Out:
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Pasta criada com sucesso!
# Pasta criada com sucesso!
# Pasta criada com sucesso!
# Pasta criada com sucesso!
# Pasta criada com sucesso!
# Pasta criada com sucesso!
# Pasta criada com sucesso!
# Pasta criada com sucesso!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Pasta criada com sucesso!
# Pasta criada com sucesso!
# Pasta criada com sucesso!
# Pasta criada com sucesso!
# Pasta criada com sucesso!
# Pasta criada com sucesso!
# Pasta criada com sucesso!
# Pasta criada com sucesso!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Ja existe uma pasta com esse nome!
# Pasta criada com sucesso!
# Pasta criada com sucesso!
# Pasta criada com sucesso!
# Pasta criada com sucesso!
# Pasta criada com sucesso!
# Pasta criada com sucesso!
# Pasta criada com sucesso!
# Pasta criada com sucesso!
# Pasta criada com sucesso!
# Pasta criada com sucesso!
